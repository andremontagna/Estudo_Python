# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys #biblioteca de teclas do teclado
import pandas as pd
import openpyxl

# %%
# Criar navegador no Chrome

navegador = webdriver.Chrome()

# %% [markdown]
#  lendo a base de dados
#
# df = pd.read_excel(r'4_Base de dados de produtos\Produtos.xlsx')
#
# display(df)

# %%
nome = 'Arroz Integral'
autor = 'autor'
categoria = 'categoria'

# %%
navegador.get("https://www.hiperselectsupermercados.com.br") #acessa o site

busca = navegador.find_element("class name", "pt-2 mr-3 ml-3") #encontrar o elemento na página (botão de busca) 
busca.send_keys(nome) # insere o item de pesquisa
busca.send_keys(Keys.ENTER)

#lista_resultados= navegador.find_elements("class name", "booklink") # seleciona todos os resultados da pesquisa
#for resultado in lista_resultados: 
#    texto = resultado.text #lista os resultdos pelo nome
#    if nome.lower() in texto.lower():
#        print(texto)
#        link_resultado = resultado.find_element("class name","link").get_attribute("href")
#        print(link_resultado)
#        break
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 navegador.get("https://www.hiperselectsupermercados.com.br") #acessa o site
# ----> 3 busca = navegador.find_element("class name", "pt-2 mr-3 ml-3") #encontrar o elemento na página (botão de busca)
#       4 busca.send_keys(nome) # insere o item de pesquisa
#       5 busca.send_keys(Keys.ENTER)
#
# File c:\Users\Andre\OneDrive\PROGRAMACAO\GitHub\Estudo_Python\Projeto Automacao WEB\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:808, in WebDriver.find_element(self, by, value)
#     792 def find_element(self, by: str | RelativeBy = By.ID, value: str | None = None) -> WebElement:
#     793     """Find an element given a By strategy and locator.
#     794
#     795     Args:
#    (...)    806         `element = driver.find_element(By.ID, 'foo')`
#     807     """
# --> 808     by, value = self.locator_converter.convert(by, value)
#     810     if isinstance(by, RelativeBy):
#     811         elements = self.find_elements(by=by, value=value)
#
# File c:\Users\Andre\OneDrive\PROGRAMACAO\GitHub\Estudo_Python\Projeto Automacao WEB\.venv\Lib\site-packages\selenium\webdriver\remote\locator_converter.py:29, in LocatorConverter.convert(self, by, value)
#      27 elif by == By.CLASS_NAME:
#      28     if value and any(char.isspace() for char in value.strip()):
# ---> 29         raise InvalidSelectorException("Compound class names are not allowed.")
#      30     return By.CSS_SELECTOR, f".{value}"
#      31 elif by == By.NAME:
#
# InvalidSelectorException: Message: Compound class names are not allowed.; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidselectorexception
